# %%
# !git clone --depth=1 https://github.com/twintproject/twint.git
# %cd twint
# !git pull origin master
# Out:
# Cloning into 'twint'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 47 (delta 3), reused 14 (delta 0), pack-reused 0
# Unpacking objects: 100% (47/47), done.
# /content/twint
# From https://github.com/twintproject/twint
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !pip install -r requirements.txt
# !python setup.py install
# Out:
# Collecting aiohttp==3.7.0
#   Downloading aiohttp-3.7.0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 34.1 MB/s
# Requirement already satisfied: aiodns in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (4.6.3)
# Requirement already satisfied: cchardet in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (2.1.7)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (0.6)
# Requirement already satisfied: elasticsearch in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (7.16.1)
# Requirement already satisfied: pysocks in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (1.7.1)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (1.1.5)
# Requirement already satisfied: aiohttp_socks<=0.4.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (0.4.1)
# Requirement already satisfied: schedule in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: geopy in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 12)) (0.1.11)
# Requirement already satisfied: googletransx in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 13)) (2.4.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.0->-r requirements.txt (line 1)) (1.7.2)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.0->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.0->-r requirements.txt (line 1)) (5.2.0)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.0->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->-r requirements.txt (line 8)) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->-r requirements.txt (line 8)) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->-r requirements.txt (line 8)) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->-r requirements.txt (line 8)) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp==3.7.0->-r requirements.txt (line 1)) (3.10.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp==3.7.0->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from aiodns->-r requirements.txt (line 2)) (4.1.2)
# Requirement already satisfied: cffi>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pycares>=4.0.0->aiodns->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.5.0->pycares>=4.0.0->aiodns->-r requirements.txt (line 2)) (2.21)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch->-r requirements.txt (line 6)) (2021.10.8)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch->-r requirements.txt (line 6)) (1.24.3)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.7/dist-packages (from geopy->-r requirements.txt (line 11)) (1.52)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from googletransx->-r requirements.txt (line 13)) (2.23.0)
# Installing collected packages: async-timeout, aiohttp
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.2
#     Uninstalling async-timeout-4.0.2:
#       Successfully uninstalled async-timeout-4.0.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.1
#     Uninstalling aiohttp-3.8.1:
#       Successfully uninstalled aiohttp-3.8.1
# Successfully installed aiohttp-3.7.0 async-timeout-3.0.1
# running install
# running bdist_egg
# running egg_info
# writing twint.egg-info/PKG-INFO
# writing dependency_links to twint.egg-info/dependency_links.txt
# writing entry points to twint.egg-info/entry_points.txt
# writing requirements to twint.egg-info/requires.txt
# writing top-level names to twint.egg-info/top_level.txt
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'twint.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/run.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/__version__.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/verbose.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/config.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/output.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/format.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/tweet.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/url.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/__init__.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/user.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/token.py -> build/bdist.linux-x86_64/egg/twint
# creating build/bdist.linux-x86_64/egg/twint/storage
# copying build/lib/twint/storage/write.py -> build/bdist.linux-x86_64/egg/twint/storage
# copying build/lib/twint/storage/db.py -> build/bdist.linux-x86_64/egg/twint/storage
# copying build/lib/twint/storage/panda.py -> build/bdist.linux-x86_64/egg/twint/storage
# copying build/lib/twint/storage/__init__.py -> build/bdist.linux-x86_64/egg/twint/storage
# copying build/lib/twint/storage/elasticsearch.py -> build/bdist.linux-x86_64/egg/twint/storage
# copying build/lib/twint/storage/write_meta.py -> build/bdist.linux-x86_64/egg/twint/storage
# copying build/lib/twint/datelock.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/cli.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/feed.py -> build/bdist.linux-x86_64/egg/twint
# copying build/lib/twint/get.py -> build/bdist.linux-x86_64/egg/twint
# byte-compiling build/bdist.linux-x86_64/egg/twint/run.py to run.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/__version__.py to __version__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/verbose.py to verbose.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/config.py to config.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/output.py to output.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/format.py to format.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/tweet.py to tweet.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/url.py to url.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/user.py to user.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/token.py to token.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/storage/write.py to write.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/storage/db.py to db.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/storage/panda.py to panda.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/storage/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/storage/elasticsearch.py to elasticsearch.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/storage/write_meta.py to write_meta.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/datelock.py to datelock.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/cli.py to cli.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/feed.py to feed.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/twint/get.py to get.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying twint.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying twint.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying twint.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying twint.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying twint.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying twint.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/twint-2.1.21-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing twint-2.1.21-py3.7.egg
# Removing /usr/local/lib/python3.7/dist-packages/twint-2.1.21-py3.7.egg
# Copying twint-2.1.21-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# twint 2.1.21 is already the active version in easy-install.pth
# Installing twint script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/twint-2.1.21-py3.7.egg
# Processing dependencies for twint==2.1.21
# Searching for googletransx==2.4.2
# Best match: googletransx 2.4.2
# Adding googletransx 2.4.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for fake-useragent==0.1.11
# Best match: fake-useragent 0.1.11
# Adding fake-useragent 0.1.11 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for geopy==1.17.0
# Best match: geopy 1.17.0
# Adding geopy 1.17.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for schedule==1.1.0
# Best match: schedule 1.1.0
# Adding schedule 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for aiohttp-socks==0.4.1
# Best match: aiohttp-socks 0.4.1
# Adding aiohttp-socks 0.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pandas==1.1.5
# Best match: pandas 1.1.5
# Adding pandas 1.1.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for PySocks==1.7.1
# Best match: PySocks 1.7.1
# Adding PySocks 1.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for elasticsearch==7.16.1
# Best match: elasticsearch 7.16.1
# Adding elasticsearch 7.16.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for dataclasses==0.6
# Best match: dataclasses 0.6
# Adding dataclasses 0.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for cchardet==2.1.7
# Best match: cchardet 2.1.7
# Adding cchardet 2.1.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for beautifulsoup4==4.6.3
# Best match: beautifulsoup4 4.6.3
# Adding beautifulsoup4 4.6.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for aiodns==3.0.0
# Best match: aiodns 3.0.0
# Adding aiodns 3.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for aiohttp==3.7.0
# Best match: aiohttp 3.7.0
# Adding aiohttp 3.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for requests==2.23.0
# Best match: requests 2.23.0
# Adding requests 2.23.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for geographiclib==1.52
# Best match: geographiclib 1.52
# Adding geographiclib 1.52 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for attrs==21.2.0
# Best match: attrs 21.2.0
# Adding attrs 21.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numpy==1.19.5
# Best match: numpy 1.19.5
# Adding numpy 1.19.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.7 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pytz==2018.9
# Best match: pytz 2018.9
# Adding pytz 2018.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for urllib3==1.24.3
# Best match: urllib3 1.24.3
# Adding urllib3 1.24.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for certifi==2021.10.8
# Best match: certifi 2021.10.8
# Adding certifi 2021.10.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pycares==4.1.2
# Best match: pycares 4.1.2
# Adding pycares 4.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for multidict==5.2.0
# Best match: multidict 5.2.0
# Adding multidict 5.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for async-timeout==3.0.1
# Best match: async-timeout 3.0.1
# Adding async-timeout 3.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for yarl==1.7.2
# Best match: yarl 1.7.2
# Adding yarl 1.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for idna==2.10
# Best match: idna 2.10
# Adding idna 2.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for cffi==1.15.0
# Best match: cffi 1.15.0
# Adding cffi 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for typing-extensions==3.10.0.2
# Best match: typing-extensions 3.10.0.2
# Adding typing-extensions 3.10.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pycparser==2.21
# Best match: pycparser 2.21
# Adding pycparser 2.21 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for twint==2.1.21

# %%
# !pip3 install twint
# Out:
# Requirement already satisfied: twint in /usr/local/lib/python3.7/dist-packages/twint-2.1.21-py3.7.egg (2.1.21)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from twint) (3.7.0)
# Requirement already satisfied: aiodns in /usr/local/lib/python3.7/dist-packages (from twint) (3.0.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from twint) (4.6.3)
# Requirement already satisfied: cchardet in /usr/local/lib/python3.7/dist-packages (from twint) (2.1.7)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.7/dist-packages (from twint) (0.6)
# Requirement already satisfied: elasticsearch in /usr/local/lib/python3.7/dist-packages (from twint) (7.16.1)
# Requirement already satisfied: pysocks in /usr/local/lib/python3.7/dist-packages (from twint) (1.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from twint) (1.1.5)
# Requirement already satisfied: aiohttp_socks in /usr/local/lib/python3.7/dist-packages (from twint) (0.4.1)
# Requirement already satisfied: schedule in /usr/local/lib/python3.7/dist-packages (from twint) (1.1.0)
# Requirement already satisfied: geopy in /usr/local/lib/python3.7/dist-packages (from twint) (1.17.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from twint) (0.1.11)
# Requirement already satisfied: googletransx in /usr/local/lib/python3.7/dist-packages (from twint) (2.4.2)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from aiodns->twint) (4.1.2)
# Requirement already satisfied: cffi>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pycares>=4.0.0->aiodns->twint) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.5.0->pycares>=4.0.0->aiodns->twint) (2.21)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (21.2.0)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp->twint) (3.10.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp->twint) (2.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch->twint) (2021.10.8)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch->twint) (1.24.3)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.7/dist-packages (from geopy->twint) (1.52)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from googletransx->twint) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->twint) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->twint) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->twint) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->twint) (1.15.0)

# %%
# %%sh
# sudo pip install pipenv
# pipenv install git+https://github.com/twintproject/twint.git#egg=twint
# Out:
# Collecting pipenv
#   Downloading pipenv-2021.11.23-py2.py3-none-any.whl (3.6 MB)
# Collecting virtualenv-clone>=0.2.5
#   Downloading virtualenv_clone-0.5.7-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: pip>=18.0 in /usr/local/lib/python3.7/dist-packages (from pipenv) (21.1.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pipenv) (2021.10.8)
# Requirement already satisfied: setuptools>=36.2.1 in /usr/local/lib/python3.7/dist-packages (from pipenv) (57.4.0)
# Collecting virtualenv
#   Downloading virtualenv-20.10.0-py2.py3-none-any.whl (5.6 MB)
# Requirement already satisfied: filelock<4,>=3.2 in /usr/local/lib/python3.7/dist-packages (from virtualenv->pipenv) (3.4.0)
# Requirement already satisfied: six<2,>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from virtualenv->pipenv) (1.15.0)
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.4.0-py3-none-any.whl (14 kB)
# Collecting backports.entry-points-selectable>=1.0.4
#   Downloading backports.entry_points_selectable-1.1.1-py2.py3-none-any.whl (6.2 kB)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.4-py2.py3-none-any.whl (461 kB)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from virtualenv->pipenv) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->virtualenv->pipenv) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->virtualenv->pipenv) (3.6.0)
# Installing collected packages: platformdirs, distlib, backports.entry-points-selectable, virtualenv-clone, virtualenv, pipenv
# Successfully installed backports.entry-points-selectable-1.1.1 distlib-0.3.4 pipenv-2021.11.23 platformdirs-2.4.0 virtualenv-20.10.0 virtualenv-clone-0.5.7
# Installing git+https://github.com/twintproject/twint.git#egg=twint...
# Installing dependencies from Pipfile.lock (bd6984)...
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# Creating a virtualenv for this project...
# Pipfile: /content/twint/Pipfile
# Using /usr/local/bin/python (3.7.12) to create virtualenv...
# ⠴ Creating virtual environment...created virtual environment CPython3.7.12.final.0-64 in 996ms
#   creator CPython3Posix(dest=/root/.local/share/virtualenvs/twint-w0p80paI, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==21.3.1, setuptools==58.3.0, wheel==0.37.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
#
# ✔ Successfully created virtual environment!
# Virtualenv location: /root/.local/share/virtualenvs/twint-w0p80paI
# Creating a Pipfile for this project...
# Adding twint to Pipfile's [packages]...
# ✔ Installation Succeeded
# Pipfile.lock not found, creating...
# Locking [dev-packages] dependencies...
# Locking [packages] dependencies...
# Building requirements...
# Resolving dependencies...
# ✔ Success!
# Updated Pipfile.lock (bd6984)!

# %%
import twint

# Configure
c = twint.Config()

c.Search = "Muslim Retard"

# %%
import nest_asyncio
nest_asyncio.apply()
c.Store_csv=True
c.Output="Muslim Retard"

twint.run.Search(c)
# Out:
# 1473535139850424325 2021-12-22 06:05:28 +0000 <SriramArkan> Can you predict when even normal Muslims, even kids turn Jihadis in today's world? What a danger they pose to society. Shocking. And we have nincompoop retards like @cjwerleman supporting their agendas. Shame.
# 1473496232014200833 2021-12-22 03:30:52 +0000 <itsShilpiS> @ji_deepika @ajaydaga05 Really?Hv u read d news of Ujjain Mahakaleshwar Temple?A muslim man enter mandir in Bhashm Aarti wid a Hindu Id and wen he got caught no1 lynched or killed him infact handed over to the police. Y Sikh ppl hasn't done dat, he was mentally retard , stealing 2rotis was not big crime
